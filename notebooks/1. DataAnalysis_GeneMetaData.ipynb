# %%
import pandas as pd

gene_metadata_df = pd.read_excel("../data/gene_metadata_neuroblastoma.xlsx")
gene_metadat_desc = pd.read_excel("../data/gene_metadata_neuroblastoma_README.xlsx", header=None)

# %%
gene_metadata_df.columns
# Out:
# Index(['Gene Symbol', 'logFC', 'PValue', 'FDR', 'Normals', 'Tumor',
#        'gene_family', 'gene name', 'refseq_accession', 'ProteinCoding',
#        'CellSurface', 'TranscriptionFactor', 'CancerGermlineAntigen',
#        'PAX3FOXO1', 'EWSR1FL1', 'Brain.MeanExp', 'Heart.MeanExp',
#        'Kidney.MeanExp', 'Liver.MeanExp', 'Lung.MeanExp', 'Group'],
#       dtype='object')

# %%
gene_metadata_df
# Out:
#       Gene Symbol     logFC        PValue           FDR     Normals  \
# 0            A1BG -2.148187  1.874737e-13  1.264937e-12   13.689734
# 1            A1BG -0.952711  6.816670e-02  1.496914e-01   11.663404
# 2            A1BG -2.509698  2.687044e-02  1.074220e-01   11.500428
# 3             A2M -1.683172  7.676842e-17  6.588098e-16  179.205023
# 4             A2M -1.835414  2.239843e-08  1.533736e-07  160.406501
# ...           ...       ...           ...           ...         ...
# 18417      CT47A2  0.000000  1.000000e+00  1.000000e+00    0.000000
# 18418      MAGEA5  9.002042  7.611961e-24  4.936533e-21    0.001566
# 18419       TSPY1  0.000000  1.000000e+00  1.000000e+00    0.000000
# 18420     VENTXP1  6.911887  4.981908e-06  8.726633e-05    0.000000
# 18421       CALR3 -0.162442  9.956245e-01  1.000000e+00    0.009456
#
#            Tumor                                        gene_family  \
# 0       3.086820              Immunoglobulin like domain containing
# ...

# %%
gene_metadat_desc.columns = ["Column Name", "Description"]

# %%
for id, row in gene_metadat_desc.iterrows():
    print("{:25s} : {:5s}".format(row['Column Name'], row['Description']))
# Out:
# Gene Symbol               : The gene name indicated with symbols
# logFC                     : Comparing the normal expression and tumor expression in a given gene to identify  overexpression and underexpression ( + value = overexpression, - values = underexpression)
# PValue                    : Statistical signifance between differences in average normal and tumor gene expression; smaller values indicate greater significance, larger values indicates differences are likely randomized with no significance
# FDR                       : False Discovery Rate - measures statistical signifcance of the gene, use to predict the expected proportions of false positive genes; the lower the better
# Normal                    : Average gene expression in a normal tissue for that specific gene within neuroblastoma
# Tumor                     : Average gene expression in a tumor tissue for that specific gene within neuroblastoma
# ...
