# %%
import pandas as pd
from collections import defaultdict

gene_expression_df = pd.read_excel("../data/raw/sample_gene_expression_neuroblastoma.xlsx")
gene_expression_desc = pd.read_excel("../data/raw/sample_gene_expression_neuroblastoma_README.xlsx")

# %%
gene_expression_df.columns
# Out:
# Index(['Unnamed: 0', 'Sample Type', 'Tumor', 'Tumor.1', 'Tumor.2', 'Tumor.3',
#        'Tumor.4', 'Tumor.5', 'Tumor.6', 'Tumor.7',
#        ...
#        'NS.137', 'NS.138', 'NS.139', 'NS.140', 'NS.141', 'NS.142', 'NS.143',
#        'NS.144', 'NS.145', 'NS.146'],
#       dtype='object', length=395)

# %%
gene_expression_df
# Out:
#            Unnamed: 0  Sample Type  \
# 0          Ensembl ID  Gene Symbol
# 1     ENSG00000121410         A1BG
# 2     ENSG00000175899          A2M
# 3     ENSG00000166535        A2ML1
# 4     ENSG00000128274       A4GALT
# ...               ...          ...
# 6127  ENSG00000204375       XAGE1E
# 6128  ENSG00000185751        XAGE2
# 6129  ENSG00000171402        XAGE3
# 6130  ENSG00000171405        XAGE5
# 6131  ENSG00000175809       ZNF645
#
#                                                  Tumor  \
# 0     NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1                                             0.987836
# 2                                             4.771729
# 3                                                    0
# 4                                             0.940922
# ...                                                ...
# 6127                                          0.015002
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.1  \
# 0     NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 1                                             1.458878
# 2                                              6.10215
# 3                                                    0
# 4                                             2.478532
# ...                                                ...
# 6127                                                 0
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.2  \
# 0     NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 1                                             0.879737
# 2                                             3.064619
# 3                                             0.006537
# 4                                             0.332491
# ...                                                ...
# 6127                                                 0
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.3  \
# 0     NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 1                                             1.759617
# 2                                             6.210056
# 3                                                    0
# 4                                             2.228315
# ...                                                ...
# 6127                                                 0
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                          0.031542
#
#                                                Tumor.4  \
# 0     NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# 1                                             2.410172
# 2                                             6.710592
# 3                                             0.003568
# 4                                             2.819369
# ...                                                ...
# 6127                                          0.146121
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.5  \
# 0     NB.MYCN.A.Tumor.PAPUNH_Alive_High.Risk_Amplified
# 1                                             1.917251
# 2                                             2.215601
# 3                                              0.01766
# 4                                              0.35549
# ...                                                ...
# 6127                                          0.153385
# 6128                                                 0
# 6129                                          0.033376
# 6130                                          0.299215
# 6131                                                 0
#
#                                                Tumor.6  \
# 0     NB.MYCN.A.Tumor.PAPZYP_Alive_High.Risk_Amplified
# 1                                             1.440319
# 2                                             6.152289
# 3                                                    0
# 4                                             2.173267
# ...                                                ...
# 6127                                          0.080812
# 6128                                                 0
# 6129                                           0.03838
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.7  ...           NS.137  \
# 0     NB.MYCN.A.Tumor.PAPZYZ_Alive_High.Risk_Amplified  ...  NS.ureter.NS171
# 1                                             1.785339  ...         0.665534
# 2                                               7.6245  ...         6.363013
# 3                                                    0  ...         0.091691
# 4                                             3.358186  ...         2.850943
# ...                                                ...  ...              ...
# 6127                                          0.139717  ...                0
# 6128                                                 0  ...                0
# 6129                                                 0  ...                0
# 6130                                          0.045085  ...                0
# 6131                                                 0  ...                0
#
#                NS.138           NS.139           NS.140           NS.141  \
# 0     NS.ureter.NS172  NS.ureter.NS173  NS.uterus.NS185  NS.uterus.NS177
# 1            0.879104         0.421156         0.660868         0.553003
# 2            6.806819         6.139101         7.107079          6.54423
# 3            0.131466         0.150304         0.007645         0.058151
# 4            4.178136         4.003085         3.406599         1.636608
# ...               ...              ...              ...              ...
# 6127                0                0                0                0
# 6128                0                0                0                0
# 6129                0                0                0                0
# 6130                0                0                0                0
# 6131         0.102763                0                0                0
#
#                NS.142           NS.143           NS.144           NS.145  \
# 0     NS.uterus.NS178  NS.uterus.NS180  NS.uterus.NS186  NS.uterus.NS184
# 1            0.490898         0.550141         0.569498         0.438346
# 2            7.305137         6.714097          6.78923         6.761142
# 3            0.091356         0.068717         0.356167         0.094883
# 4            2.337835          1.67405         4.443948         1.905303
# ...               ...              ...              ...              ...
# 6127                0                0                0                0
# 6128                0                0                0                0
# 6129                0                0                0                0
# 6130                0                0                0                0
# 6131         0.097959         0.160879                0         0.026113
#
#                NS.146
# 0     NS.uterus.NS181
# 1            0.407911
# 2            7.126564
# 3            0.042002
# 4            2.331096
# ...               ...
# 6127                0
# 6128                0
# 6129                0
# 6130                0
# 6131         0.050632
#
# [6132 rows x 395 columns]

# %%
temp_df = pd.DataFrame(gene_expression_df.iloc[0][2:]).reset_index().rename(columns={"index": "Sample Type", 0: "Patient"})
temp_df["Sample Type"] = temp_df["Sample Type"].apply(lambda x: x.split(".")[0])
temp_df
# Out:
#     Sample Type                                           Patient
# 0         Tumor  NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1         Tumor  NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 2         Tumor  NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 3         Tumor  NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 4         Tumor  NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# ..          ...                                               ...
# 388          NS                                   NS.uterus.NS178
# 389          NS                                   NS.uterus.NS180
# 390          NS                                   NS.uterus.NS186
# 391          NS                                   NS.uterus.NS184
# 392          NS                                   NS.uterus.NS181
#
# [393 rows x 2 columns]

# %%
s = "NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified"
s.split(".")
# Out:
# ['NB', 'MYCN', 'A', 'Tumor', 'PALZZV_Alive_High', 'Risk_Amplified']

# %%
# Schema
## Tumor
# Cancer.MYCN gene.Not amplified/Amplified.Sample Type.Patient ID.Status.Risk Level.Nonamplified/Amplified

## CellLine
# Cancer. MYCN gene. Amplified/Not-amplified.Sample Type.Patient ID)

## NS
# Normal sample. Location of tissue. Identification


def process_risk_level(x):         
    if x[-1][:4] == "Risk":
        x[-2] = x[-2] + x[-1]
        return x[:-1]
    if x[-2][:4] == "Risk":
        x[-2] = x[-2] + x[-1]
        x[-3] = x[-3] + x[-2]
        return x[:-2]
    if "Amplified" in x[-1]:
        if x[-2] != "Tumor":
            x[-2] = x[-2] + x[-1]
            return x[:-1]
    return x

# %%
temp_df["Patient_info_parsed"] = temp_df["Patient"].apply(lambda x: x.split("."))
temp_df["Patient_info_parsed"] = temp_df["Patient_info_parsed"].apply(lambda x: process_risk_level(x))

# %%
for id, row in temp_df.iterrows():
    print(row["Patient"], row['Patient_info_parsed'])
# Out:
# NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PALEVG_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PALKUC_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PALZZV_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAMZGT_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPBJE_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPUNH_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPUNH_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPZYP_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPZYP_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPZYZ_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPZYZ_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASSRN_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASSRN_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASWYR_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASWYR_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASXIE_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASXIE_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASXRG_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASXRG_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PATDWN_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PATDWN_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PATDXG_Alive_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PATDXG_Alive_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASJZC_Alive_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASJZC_Alive_Amplified']
# NB.MYCN.A.Tumor.PAMBMJ_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAMBMJ_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAMEZH_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAMEZH_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAMMXF_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAMMXF_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAMZMG_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAMZMG_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PANJLH_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PANJLH_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PANUKV_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PANUKV_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPCTS_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPCTS_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPEFE_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPEFE_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPKWN_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPKWN_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPTFZ_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPTFZ_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PAPTLV_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PAPTLV_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASNZU_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASNZU_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASVRU_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASVRU_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASWFB_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASWFB_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASZPI_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASZPI_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PATESI_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PATESI_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PATFXV_Dead_High.Risk_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PATFXV_Dead_HighRisk_Amplified']
# NB.MYCN.A.Tumor.PASHFA_D_Dead_Amplified ['NB', 'MYCN', 'A', 'Tumor', 'PASHFA_D_Dead_Amplified']
# NB.MYCN.A.Tumor.NB21 ['NB', 'MYCN', 'A', 'Tumor', 'NB21']
# NB.MYCN.A.Tumor.NB265 ['NB', 'MYCN', 'A', 'Tumor', 'NB265']
# NB.MYCN.A.Tumor.NB266 ['NB', 'MYCN', 'A', 'Tumor', 'NB266']
# NB.MYCN.A.Tumor.NB27 ['NB', 'MYCN', 'A', 'Tumor', 'NB27']
# NB.MYCN.A.Tumor.NB278 ['NB', 'MYCN', 'A', 'Tumor', 'NB278']
# NB.MYCN.A.Tumor.NB541 ['NB', 'MYCN', 'A', 'Tumor', 'NB541']
# NB.MYCN.A.Tumor.NB545 ['NB', 'MYCN', 'A', 'Tumor', 'NB545']
# NB.MYCN.A.Tumor.NB547 ['NB', 'MYCN', 'A', 'Tumor', 'NB547']
# NB.MYCN.A.Tumor.NB581 ['NB', 'MYCN', 'A', 'Tumor', 'NB581']
# NB.MYCN.A.Tumor.NB583 ['NB', 'MYCN', 'A', 'Tumor', 'NB583']
# NB.MYCN.A.Tumor.NCI0010 ['NB', 'MYCN', 'A', 'Tumor', 'NCI0010']
# NB.MYCN.A.Tumor.NCI0102.T2 ['NB', 'MYCN', 'A', 'Tumor', 'NCI0102', 'T2']
# NB.MYCN.A.Tumor.NCI0136.T2 ['NB', 'MYCN', 'A', 'Tumor', 'NCI0136', 'T2']
# NB.MYCN.A.Tumor.NCI0138.T1 ['NB', 'MYCN', 'A', 'Tumor', 'NCI0138', 'T1']
# NB.MYCN.NA.Tumor.PASNML_Alive_Low.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASNML_Alive_LowRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATAYJ_Alive_Low.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATAYJ_Alive_LowRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAKZRH_Alive_Intermediate.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAKZRH_Alive_IntermediateRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASCTR_Alive_Intermediate.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASCTR_Alive_IntermediateRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAIXIF_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAIXIF_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAKYZS_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAKYZS_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALCBW_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALCBW_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALNVP_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALNVP_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALXTB_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALXTB_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANGXK_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANGXK_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANKFE_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANKFE_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANNMS_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANNMS_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANRRW_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANRRW_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANRVJ_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANRVJ_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANUIF_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANUIF_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANXJL_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANXJL_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPEAV_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPEAV_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPTAN_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPTAN_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPUAR_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPUAR_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPUEB_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPUEB_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPVRN_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPVRN_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARACM_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARACM_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARACS_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARACS_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARDCK_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARDCK_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARDIW_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARDIW_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARYNK_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARYNK_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARZIP_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARZIP_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASGUT_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASGUT_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASNEF_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASNEF_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASPER_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASPER_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASRFS_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASRFS_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASTKC_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASTKC_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASUCB_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASUCB_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASUYG_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASUYG_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASWIJ_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASWIJ_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASWVY_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASWVY_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASXGP_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASXGP_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASXHE_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASXHE_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASXRJ_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASXRJ_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASYPX_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASYPX_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATBMM_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATBMM_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATCFL_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATCFL_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATEKG_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATEKG_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATHVK_Alive_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATHVK_Alive_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANZRV_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANZRV_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PAPICY_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPICY_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PAPTDH_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPTDH_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARBAJ_D_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARBAJ_D_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARBAJ_R_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARBAJ_R_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARFRE_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARFRE_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARJVP_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARJVP_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARNNC_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARNNC_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARZCJ_D_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARZCJ_D_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PARZHA_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARZHA_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASCFC_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASCFC_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASFIC_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASFIC_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASMDM_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASMDM_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASNPG_D_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASNPG_D_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASNPG_R_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASNPG_R_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASPBZ_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASPBZ_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PASSWW_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASSWW_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PATGJU_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATGJU_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PATHKB_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATHKB_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PAUDDK_D_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAUDDK_D_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PAUDDK_R_Alive_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAUDDK_R_Alive_NotAmplified']
# NB.MYCN.NA.Tumor.PAIFXV_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAIFXV_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAIPGU_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAIPGU_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAISNS_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAISNS_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAITCI_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAITCI_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAITEG_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAITEG_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAIVHE_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAIVHE_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALBFW_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALBFW_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALETP_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALETP_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALIIN_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALIIN_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALTEG_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALTEG_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALUYS_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALUYS_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALVKK_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALVKK_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PALWVJ_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PALWVJ_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAMNLH_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAMNLH_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAMVRA_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAMVRA_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAMYCE_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAMYCE_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANBJH_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANBJH_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANBMJ_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANBMJ_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANBSP_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANBSP_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANLET_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANLET_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANRHJ_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANRHJ_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANSBN_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANSBN_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANWRR_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANWRR_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANYGR_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANYGR_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANZPV_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANZPV_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PANZVU_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PANZVU_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPBGH_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPBGH_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPBZI_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPBZI_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPHPE_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPHPE_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPKXS_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPKXS_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPLSD_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPLSD_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPUWY_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPUWY_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPVFD_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPVFD_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPVXS_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPVXS_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARAMT_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARAMT_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARBGP_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARBGP_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARFWB_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARFWB_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARGKK_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARGKK_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARKGJ_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARKGJ_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARSBI_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARSBI_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PARVLK_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARVLK_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASEGA_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASEGA_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASFGG_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASFGG_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASMJG_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASMJG_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASMNT_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASMNT_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASSRS_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASSRS_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PASTCN_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASTCN_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATDXC_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATDXC_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATEPF_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATEPF_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATFCY_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATFCY_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATGLU_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATGLU_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PATINJ_Dead_High.Risk_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATINJ_Dead_HighRisk_NotAmplified']
# NB.MYCN.NA.Tumor.PAPVEB_R_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PAPVEB_R_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PARHAM_D_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARHAM_D_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PARHAM_R_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PARHAM_R_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PASGAP_D_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASGAP_D_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PASGAP_R_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASGAP_R_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PASUML_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASUML_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PASZKE_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PASZKE_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PATNKP_R_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATNKP_R_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PATYIL_D_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATYIL_D_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.PATYIL_R_Dead_Not.Amplified ['NB', 'MYCN', 'NA', 'Tumor', 'PATYIL_R_Dead_NotAmplified']
# NB.MYCN.NA.Tumor.NB106 ['NB', 'MYCN', 'NA', 'Tumor', 'NB106']
# NB.MYCN.NA.Tumor.NB107 ['NB', 'MYCN', 'NA', 'Tumor', 'NB107']
# NB.MYCN.NA.Tumor.NB12 ['NB', 'MYCN', 'NA', 'Tumor', 'NB12']
# NB.MYCN.NA.Tumor.NB236 ['NB', 'MYCN', 'NA', 'Tumor', 'NB236']
# NB.MYCN.NA.Tumor.NB239 ['NB', 'MYCN', 'NA', 'Tumor', 'NB239']
# NB.MYCN.NA.Tumor.NB40 ['NB', 'MYCN', 'NA', 'Tumor', 'NB40']
# NB.MYCN.NA.Tumor.NB82 ['NB', 'MYCN', 'NA', 'Tumor', 'NB82']
# NB.MYCN.NA.Tumor.NB84 ['NB', 'MYCN', 'NA', 'Tumor', 'NB84']
# NB.MYCN.NA.Tumor.NB89 ['NB', 'MYCN', 'NA', 'Tumor', 'NB89']
# NB.MYCN.NA.Tumor.NB205 ['NB', 'MYCN', 'NA', 'Tumor', 'NB205']
# NB.MYCN.NA.Tumor.NB206 ['NB', 'MYCN', 'NA', 'Tumor', 'NB206']
# NB.MYCN.NA.Tumor.NB207 ['NB', 'MYCN', 'NA', 'Tumor', 'NB207']
# NB.MYCN.NA.Tumor.NB209 ['NB', 'MYCN', 'NA', 'Tumor', 'NB209']
# NB.MYCN.NA.Tumor.NB210 ['NB', 'MYCN', 'NA', 'Tumor', 'NB210']
# NB.MYCN.NA.Tumor.NB283 ['NB', 'MYCN', 'NA', 'Tumor', 'NB283']
# NB.MYCN.NA.Tumor.NB536 ['NB', 'MYCN', 'NA', 'Tumor', 'NB536']
# NB.MYCN.NA.Tumor.NB540 ['NB', 'MYCN', 'NA', 'Tumor', 'NB540']
# NB.MYCN.NA.Tumor.NB586 ['NB', 'MYCN', 'NA', 'Tumor', 'NB586']
# NB.MYCN.NA.Tumor.NB8 ['NB', 'MYCN', 'NA', 'Tumor', 'NB8']
# NB.MYCN.NA.Tumor.NCI0157 ['NB', 'MYCN', 'NA', 'Tumor', 'NCI0157']
# NB.Unknown.Tumor.PAPTCR_Dead_High.Risk_Unknown ['NB', 'Unknown', 'Tumor', 'PAPTCR_Dead_HighRisk_Unknown']
# NB.Unknown.Tumor.NB62 ['NB', 'Unknown', 'Tumor', 'NB62']
# NB.Unknown.Tumor.NCI0002 ['NB', 'Unknown', 'Tumor', 'NCI0002']
# NB.Unknown.Tumor.NCI0005 ['NB', 'Unknown', 'Tumor', 'NCI0005']
# NB.Unknown.Tumor.NCI0011 ['NB', 'Unknown', 'Tumor', 'NCI0011']
# NB.Unknown.Tumor.NCI0015 ['NB', 'Unknown', 'Tumor', 'NCI0015']
# NB.Unknown.Tumor.NCI0017 ['NB', 'Unknown', 'Tumor', 'NCI0017']
# NB.Unknown.Tumor.NCI0017.T3 ['NB', 'Unknown', 'Tumor', 'NCI0017', 'T3']
# NB.Unknown.Tumor.NCI0017.T4 ['NB', 'Unknown', 'Tumor', 'NCI0017', 'T4']
# NB.Unknown.Tumor.NCI0108 ['NB', 'Unknown', 'Tumor', 'NCI0108']
# NB.Unknown.Tumor.NCI0117 ['NB', 'Unknown', 'Tumor', 'NCI0117']
# NB.Unknown.Tumor.NCI0231 ['NB', 'Unknown', 'Tumor', 'NCI0231']
# NB.MYCN.A.CellLine.CHP134 ['NB', 'MYCN', 'A', 'CellLine', 'CHP134']
# NB.MYCN.A.CellLine.CHP-212 ['NB', 'MYCN', 'A', 'CellLine', 'CHP-212']
# NB.MYCN.A.CellLine.COGN415 ['NB', 'MYCN', 'A', 'CellLine', 'COGN415']
# NB.MYCN.A.CellLine.COGN440 ['NB', 'MYCN', 'A', 'CellLine', 'COGN440']
# NB.MYCN.A.CellLine.COGN453 ['NB', 'MYCN', 'A', 'CellLine', 'COGN453']
# NB.MYCN.A.CellLine.COGN471 ['NB', 'MYCN', 'A', 'CellLine', 'COGN471']
# NB.MYCN.A.CellLine.COGN496 ['NB', 'MYCN', 'A', 'CellLine', 'COGN496']
# NB.MYCN.A.CellLine.COGN519 ['NB', 'MYCN', 'A', 'CellLine', 'COGN519']
# NB.MYCN.A.CellLine.COGN561 ['NB', 'MYCN', 'A', 'CellLine', 'COGN561']
# NB.MYCN.A.CellLine.COGN573 ['NB', 'MYCN', 'A', 'CellLine', 'COGN573']
# NB.MYCN.A.CellLine.GILIN ['NB', 'MYCN', 'A', 'CellLine', 'GILIN']
# NB.MYCN.A.CellLine.IMR32 ['NB', 'MYCN', 'A', 'CellLine', 'IMR32']
# NB.MYCN.A.CellLine.IMR5 ['NB', 'MYCN', 'A', 'CellLine', 'IMR5']
# NB.MYCN.A.CellLine.KCNR ['NB', 'MYCN', 'A', 'CellLine', 'KCNR']
# NB.MYCN.A.CellLine.KELLY ['NB', 'MYCN', 'A', 'CellLine', 'KELLY']
# NB.MYCN.A.CellLine.LAN1 ['NB', 'MYCN', 'A', 'CellLine', 'LAN1']
# NB.MYCN.A.CellLine.LAN5 ['NB', 'MYCN', 'A', 'CellLine', 'LAN5']
# NB.MYCN.A.CellLine.NB1 ['NB', 'MYCN', 'A', 'CellLine', 'NB1']
# NB.MYCN.A.CellLine.NB1643 ['NB', 'MYCN', 'A', 'CellLine', 'NB1643']
# NB.MYCN.A.CellLine.NB1691 ['NB', 'MYCN', 'A', 'CellLine', 'NB1691']
# NB.MYCN.A.CellLine.NBSD ['NB', 'MYCN', 'A', 'CellLine', 'NBSD']
# NB.MYCN.A.CellLine.NGP ['NB', 'MYCN', 'A', 'CellLine', 'NGP']
# NB.MYCN.A.CellLine.NLF ['NB', 'MYCN', 'A', 'CellLine', 'NLF']
# NB.MYCN.A.CellLine.NMB ['NB', 'MYCN', 'A', 'CellLine', 'NMB']
# NB.MYCN.A.CellLine.SKNBE2 ['NB', 'MYCN', 'A', 'CellLine', 'SKNBE2']
# NB.MYCN.A.CellLine.SKNDZ ['NB', 'MYCN', 'A', 'CellLine', 'SKNDZ']
# NB.MYCN.A.CellLine.SMSKAN ['NB', 'MYCN', 'A', 'CellLine', 'SMSKAN']
# NB.MYCN.A.CellLine.SMSSAN ['NB', 'MYCN', 'A', 'CellLine', 'SMSSAN']
# NB.MYCN.NA.CellLine.COGN534 ['NB', 'MYCN', 'NA', 'CellLine', 'COGN534']
# NB.MYCN.NA.CellLine.COGN549 ['NB', 'MYCN', 'NA', 'CellLine', 'COGN549']
# NB.MYCN.NA.CellLine.FELIX ['NB', 'MYCN', 'NA', 'CellLine', 'FELIX']
# NB.MYCN.NA.CellLine.LAN6 ['NB', 'MYCN', 'NA', 'CellLine', 'LAN6']
# NB.MYCN.NA.CellLine.NB16 ['NB', 'MYCN', 'NA', 'CellLine', 'NB16']
# NB.MYCN.NA.CellLine.NB69 ['NB', 'MYCN', 'NA', 'CellLine', 'NB69']
# NB.MYCN.NA.CellLine.NBEB ['NB', 'MYCN', 'NA', 'CellLine', 'NBEB']
# NB.MYCN.NA.CellLine.NBLS ['NB', 'MYCN', 'NA', 'CellLine', 'NBLS']
# NB.MYCN.NA.CellLine.SHSY5Y ['NB', 'MYCN', 'NA', 'CellLine', 'SHSY5Y']
# NB.MYCN.NA.CellLine.SKNAS ['NB', 'MYCN', 'NA', 'CellLine', 'SKNAS']
# NB.MYCN.NA.CellLine.SKNFI ['NB', 'MYCN', 'NA', 'CellLine', 'SKNFI']
# NB.MYCN.NA.CellLine.SKNSH ['NB', 'MYCN', 'NA', 'CellLine', 'SKNSH']
# NS.adrenalgland.NS007 ['NS', 'adrenalgland', 'NS007']
# NS.adrenalgland.NS008 ['NS', 'adrenalgland', 'NS008']
# NS.adrenalgland.NS003 ['NS', 'adrenalgland', 'NS003']
# NS.adrenalgland.NS005 ['NS', 'adrenalgland', 'NS005']
# NS.adrenalgland.NS001 ['NS', 'adrenalgland', 'NS001']
# NS.adrenalgland.NS006 ['NS', 'adrenalgland', 'NS006']
# NS.adrenalgland.NS002 ['NS', 'adrenalgland', 'NS002']
# NS.adrenalgland.NS009 ['NS', 'adrenalgland', 'NS009']
# NS.bladder.NS017 ['NS', 'bladder', 'NS017']
# NS.bladder.NS012 ['NS', 'bladder', 'NS012']
# NS.bladder.NS019 ['NS', 'bladder', 'NS019']
# NS.bladder.NS011 ['NS', 'bladder', 'NS011']
# NS.bladder.NS013 ['NS', 'bladder', 'NS013']
# NS.bladder.NS014 ['NS', 'bladder', 'NS014']
# NS.bladder.NS015 ['NS', 'bladder', 'NS015']
# NS.bladder.NS016 ['NS', 'bladder', 'NS016']
# NS.cerebellum.NS026 ['NS', 'cerebellum', 'NS026']
# NS.cerebellum.NS029 ['NS', 'cerebellum', 'NS029']
# NS.cerebellum.NS021 ['NS', 'cerebellum', 'NS021']
# NS.cerebellum.NS022 ['NS', 'cerebellum', 'NS022']
# NS.cerebellum.NS023 ['NS', 'cerebellum', 'NS023']
# NS.cerebellum.NS028 ['NS', 'cerebellum', 'NS028']
# NS.cerebellum.NS024 ['NS', 'cerebellum', 'NS024']
# NS.cerebellum.NS025 ['NS', 'cerebellum', 'NS025']
# NS.cerebellum.NS027 ['NS', 'cerebellum', 'NS027']
# NS.cerebellum.NS020 ['NS', 'cerebellum', 'NS020']
# NS.cerebrum.NS037 ['NS', 'cerebrum', 'NS037']
# NS.cerebrum.NS032 ['NS', 'cerebrum', 'NS032']
# NS.cerebrum.NS033 ['NS', 'cerebrum', 'NS033']
# NS.cerebrum.NS034 ['NS', 'cerebrum', 'NS034']
# NS.cerebrum.NS035 ['NS', 'cerebrum', 'NS035']
# NS.cerebrum.NS030 ['NS', 'cerebrum', 'NS030']
# NS.cerebrum.NS036 ['NS', 'cerebrum', 'NS036']
# NS.cerebrum.NS031 ['NS', 'cerebrum', 'NS031']
# NS.colon.NS039 ['NS', 'colon', 'NS039']
# NS.colon.NS043 ['NS', 'colon', 'NS043']
# NS.colon.NS044 ['NS', 'colon', 'NS044']
# NS.colon.NS045 ['NS', 'colon', 'NS045']
# NS.colon.NS040 ['NS', 'colon', 'NS040']
# NS.colon.NS041 ['NS', 'colon', 'NS041']
# NS.colon.NS047 ['NS', 'colon', 'NS047']
# NS.colon.NS048 ['NS', 'colon', 'NS048']
# NS.colon.NS046 ['NS', 'colon', 'NS046']
# NS.heart.NS055 ['NS', 'heart', 'NS055']
# NS.heart.NS049 ['NS', 'heart', 'NS049']
# NS.heart.NS051 ['NS', 'heart', 'NS051']
# NS.heart.NS052 ['NS', 'heart', 'NS052']
# NS.heart.NS057 ['NS', 'heart', 'NS057']
# NS.heart.NS054 ['NS', 'heart', 'NS054']
# NS.heart.NS056 ['NS', 'heart', 'NS056']
# NS.ileum.NS065 ['NS', 'ileum', 'NS065']
# NS.ileum.NS068 ['NS', 'ileum', 'NS068']
# NS.ileum.NS062 ['NS', 'ileum', 'NS062']
# NS.ileum.NS059 ['NS', 'ileum', 'NS059']
# NS.ileum.NS063 ['NS', 'ileum', 'NS063']
# NS.ileum.NS060 ['NS', 'ileum', 'NS060']
# NS.ileum.NS064 ['NS', 'ileum', 'NS064']
# NS.ileum.NS061 ['NS', 'ileum', 'NS061']
# NS.kidney.NS077 ['NS', 'kidney', 'NS077']
# NS.kidney.NS078 ['NS', 'kidney', 'NS078']
# NS.kidney.NS072 ['NS', 'kidney', 'NS072']
# NS.kidney.NS073 ['NS', 'kidney', 'NS073']
# NS.kidney.NS069 ['NS', 'kidney', 'NS069']
# NS.kidney.NS074 ['NS', 'kidney', 'NS074']
# NS.kidney.NS076 ['NS', 'kidney', 'NS076']
# NS.kidney.NS070 ['NS', 'kidney', 'NS070']
# NS.liver.NS087 ['NS', 'liver', 'NS087']
# NS.liver.NS080 ['NS', 'liver', 'NS080']
# NS.liver.NS081 ['NS', 'liver', 'NS081']
# NS.liver.NS088 ['NS', 'liver', 'NS088']
# NS.liver.NS084 ['NS', 'liver', 'NS084']
# NS.liver.NS083 ['NS', 'liver', 'NS083']
# NS.liver.NS086 ['NS', 'liver', 'NS086']
# NS.liver.NS079 ['NS', 'liver', 'NS079']
# NS.lung.NS096 ['NS', 'lung', 'NS096']
# NS.lung.NS098 ['NS', 'lung', 'NS098']
# NS.lung.NS091 ['NS', 'lung', 'NS091']
# NS.lung.NS092 ['NS', 'lung', 'NS092']
# NS.lung.NS093 ['NS', 'lung', 'NS093']
# NS.lung.NS089 ['NS', 'lung', 'NS089']
# NS.lung.NS095 ['NS', 'lung', 'NS095']
# NS.lung.NS097 ['NS', 'lung', 'NS097']
# NS.ovary.NS103 ['NS', 'ovary', 'NS103']
# NS.ovary.NS099 ['NS', 'ovary', 'NS099']
# NS.ovary.NS106 ['NS', 'ovary', 'NS106']
# NS.ovary.NS105 ['NS', 'ovary', 'NS105']
# NS.ovary.NS102 ['NS', 'ovary', 'NS102']
# NS.pancreas.NS113 ['NS', 'pancreas', 'NS113']
# NS.pancreas.NS116 ['NS', 'pancreas', 'NS116']
# NS.pancreas.NS111 ['NS', 'pancreas', 'NS111']
# NS.pancreas.NS108 ['NS', 'pancreas', 'NS108']
# NS.pancreas.NS112 ['NS', 'pancreas', 'NS112']
# NS.pancreas.NS114 ['NS', 'pancreas', 'NS114']
# NS.prostate.NS120 ['NS', 'prostate', 'NS120']
# NS.prostate.NS123 ['NS', 'prostate', 'NS123']
# NS.prostate.NS126 ['NS', 'prostate', 'NS126']
# NS.prostate.NS125 ['NS', 'prostate', 'NS125']
# NS.prostate.NS121 ['NS', 'prostate', 'NS121']
# NS.prostate.NS124 ['NS', 'prostate', 'NS124']
# NS.prostate.NS118 ['NS', 'prostate', 'NS118']
# NS.prostate.NS122 ['NS', 'prostate', 'NS122']
# NS.prostate.NS119 ['NS', 'prostate', 'NS119']
# NS.skeletalmuscle.NCIEWS5000muscle ['NS', 'skeletalmuscle', 'NCIEWS5000muscle']
# NS.skeletalmuscle.NS130 ['NS', 'skeletalmuscle', 'NS130']
# NS.skeletalmuscle.NS131 ['NS', 'skeletalmuscle', 'NS131']
# NS.skeletalmuscle.NS129 ['NS', 'skeletalmuscle', 'NS129']
# NS.skeletalmuscle.NS133 ['NS', 'skeletalmuscle', 'NS133']
# NS.skeletalmuscle.NS134 ['NS', 'skeletalmuscle', 'NS134']
# NS.skeletalmuscle.NS127 ['NS', 'skeletalmuscle', 'NS127']
# NS.skeletalmuscle.NS132 ['NS', 'skeletalmuscle', 'NS132']
# NS.skeletalmuscle.NS135 ['NS', 'skeletalmuscle', 'NS135']
# NS.skeletalmuscle.NS136 ['NS', 'skeletalmuscle', 'NS136']
# NS.skeletalmuscle.NS128 ['NS', 'skeletalmuscle', 'NS128']
# NS.spleen.NS146 ['NS', 'spleen', 'NS146']
# NS.spleen.NS139 ['NS', 'spleen', 'NS139']
# NS.spleen.NS137 ['NS', 'spleen', 'NS137']
# NS.spleen.NS143 ['NS', 'spleen', 'NS143']
# NS.spleen.NS145 ['NS', 'spleen', 'NS145']
# NS.stomach.NS152 ['NS', 'stomach', 'NS152']
# NS.stomach.NS156 ['NS', 'stomach', 'NS156']
# NS.stomach.NS149 ['NS', 'stomach', 'NS149']
# NS.stomach.NS150 ['NS', 'stomach', 'NS150']
# NS.stomach.NS151 ['NS', 'stomach', 'NS151']
# NS.stomach.NS147 ['NS', 'stomach', 'NS147']
# NS.stomach.NS153 ['NS', 'stomach', 'NS153']
# NS.testis.NS165 ['NS', 'testis', 'NS165']
# NS.testis.NS166 ['NS', 'testis', 'NS166']
# NS.testis.NS162 ['NS', 'testis', 'NS162']
# NS.testis.NS159 ['NS', 'testis', 'NS159']
# NS.testis.NS158 ['NS', 'testis', 'NS158']
# NS.testis.NS161 ['NS', 'testis', 'NS161']
# NS.testis.NS160 ['NS', 'testis', 'NS160']
# NS.thyroid.NCI0228normal ['NS', 'thyroid', 'NCI0228normal']
# NS.ureter.NS170 ['NS', 'ureter', 'NS170']
# NS.ureter.NS169 ['NS', 'ureter', 'NS169']
# NS.ureter.NS174 ['NS', 'ureter', 'NS174']
# NS.ureter.NS175 ['NS', 'ureter', 'NS175']
# NS.ureter.NS171 ['NS', 'ureter', 'NS171']
# NS.ureter.NS172 ['NS', 'ureter', 'NS172']
# NS.ureter.NS173 ['NS', 'ureter', 'NS173']
# NS.uterus.NS185 ['NS', 'uterus', 'NS185']
# NS.uterus.NS177 ['NS', 'uterus', 'NS177']
# NS.uterus.NS178 ['NS', 'uterus', 'NS178']
# NS.uterus.NS180 ['NS', 'uterus', 'NS180']
# NS.uterus.NS186 ['NS', 'uterus', 'NS186']
# NS.uterus.NS184 ['NS', 'uterus', 'NS184']
# NS.uterus.NS181 ['NS', 'uterus', 'NS181']

# %%
temp_df["Patient_info_parsed_length"] = temp_df["Patient_info_parsed"].apply(lambda x: len(x))
temp_df
# Out:
#     Sample Type                                           Patient  \
# 0         Tumor  NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1         Tumor  NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 2         Tumor  NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 3         Tumor  NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 4         Tumor  NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# ..          ...                                               ...
# 388          NS                                   NS.uterus.NS178
# 389          NS                                   NS.uterus.NS180
# 390          NS                                   NS.uterus.NS186
# 391          NS                                   NS.uterus.NS184
# 392          NS                                   NS.uterus.NS181
#
#                                    Patient_info_parsed  \
# 0    [NB, MYCN, A, Tumor, PALEVG_Alive_HighRisk_Amp...
# 1    [NB, MYCN, A, Tumor, PALKUC_Alive_HighRisk_Amp...
# 2    [NB, MYCN, A, Tumor, PALZZV_Alive_HighRisk_Amp...
# 3    [NB, MYCN, A, Tumor, PAMZGT_Alive_HighRisk_Amp...
# 4    [NB, MYCN, A, Tumor, PAPBJE_Alive_HighRisk_Amp...
# ..                                                 ...
# 388                                [NS, uterus, NS178]
# 389                                [NS, uterus, NS180]
# 390                                [NS, uterus, NS186]
# 391                                [NS, uterus, NS184]
# 392                                [NS, uterus, NS181]
#
#      Patient_info_parsed_length
# 0                             5
# 1                             5
# 2                             5
# 3                             5
# 4                             5
# ..                          ...
# 388                           3
# 389                           3
# 390                           3
# 391                           3
# 392                           3
#
# [393 rows x 4 columns]

# %%
temp_df["Patient_info_parsed_length"].value_counts()
# Out:
# Patient_info_parsed_length
# 5    233
# 3    147
# 4     10
# 6      3
# Name: count, dtype: int64

# %%
tumor_patients_df = temp_df[temp_df["Sample Type"] == "Tumor"]
tumor_patients_df
# Out:
#     Sample Type                                           Patient  \
# 0         Tumor  NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1         Tumor  NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 2         Tumor  NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 3         Tumor  NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 4         Tumor  NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# ..          ...                                               ...
# 201       Tumor                       NB.Unknown.Tumor.NCI0017.T3
# 202       Tumor                       NB.Unknown.Tumor.NCI0017.T4
# 203       Tumor                          NB.Unknown.Tumor.NCI0108
# 204       Tumor                          NB.Unknown.Tumor.NCI0117
# 205       Tumor                          NB.Unknown.Tumor.NCI0231
#
#                                    Patient_info_parsed  \
# 0    [NB, MYCN, A, Tumor, PALEVG_Alive_HighRisk_Amp...
# 1    [NB, MYCN, A, Tumor, PALKUC_Alive_HighRisk_Amp...
# 2    [NB, MYCN, A, Tumor, PALZZV_Alive_HighRisk_Amp...
# 3    [NB, MYCN, A, Tumor, PAMZGT_Alive_HighRisk_Amp...
# 4    [NB, MYCN, A, Tumor, PAPBJE_Alive_HighRisk_Amp...
# ..                                                 ...
# 201                  [NB, Unknown, Tumor, NCI0017, T3]
# 202                  [NB, Unknown, Tumor, NCI0017, T4]
# 203                      [NB, Unknown, Tumor, NCI0108]
# 204                      [NB, Unknown, Tumor, NCI0117]
# 205                      [NB, Unknown, Tumor, NCI0231]
#
#      Patient_info_parsed_length
# 0                             5
# 1                             5
# 2                             5
# 3                             5
# 4                             5
# ..                          ...
# 201                           5
# 202                           5
# 203                           4
# 204                           4
# 205                           4
#
# [206 rows x 4 columns]

# %%
tumor_patients_df["Patient_info_parsed_length"].value_counts()

#
# Out:
# Patient_info_parsed_length
# 5    193
# 4     10
# 6      3
# Name: count, dtype: int64

# %%
tumor_patients_df[tumor_patients_df["Patient_info_parsed_length"] == 5]["Patient_info_parsed"].iloc[65]
# Out:
# ['NB', 'MYCN', 'NA', 'Tumor', 'PARACM_Alive_HighRisk_NotAmplified']

# %%
tumor_patients_df
# Out:
#     Sample Type                                           Patient  \
# 0         Tumor  NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1         Tumor  NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 2         Tumor  NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 3         Tumor  NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 4         Tumor  NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# ..          ...                                               ...
# 201       Tumor                       NB.Unknown.Tumor.NCI0017.T3
# 202       Tumor                       NB.Unknown.Tumor.NCI0017.T4
# 203       Tumor                          NB.Unknown.Tumor.NCI0108
# 204       Tumor                          NB.Unknown.Tumor.NCI0117
# 205       Tumor                          NB.Unknown.Tumor.NCI0231
#
#                                    Patient_info_parsed  \
# 0    [NB, MYCN, A, Tumor, PALEVG_Alive_HighRisk_Amp...
# 1    [NB, MYCN, A, Tumor, PALKUC_Alive_HighRisk_Amp...
# 2    [NB, MYCN, A, Tumor, PALZZV_Alive_HighRisk_Amp...
# 3    [NB, MYCN, A, Tumor, PAMZGT_Alive_HighRisk_Amp...
# 4    [NB, MYCN, A, Tumor, PAPBJE_Alive_HighRisk_Amp...
# ..                                                 ...
# 201                  [NB, Unknown, Tumor, NCI0017, T3]
# 202                  [NB, Unknown, Tumor, NCI0017, T4]
# 203                      [NB, Unknown, Tumor, NCI0108]
# 204                      [NB, Unknown, Tumor, NCI0117]
# 205                      [NB, Unknown, Tumor, NCI0231]
#
#      Patient_info_parsed_length
# 0                             5
# 1                             5
# 2                             5
# 3                             5
# 4                             5
# ..                          ...
# 201                           5
# 202                           5
# 203                           4
# 204                           4
# 205                           4
#
# [206 rows x 4 columns]

# %%
patient_info_list = []
patient_info_split_dict = defaultdict(int)
patient_info_split_dict_unknown = defaultdict(int)
for index, row in tumor_patients_df.iterrows():
    t_level = None
    d_or_r = None

    if row["Patient_info_parsed_length"] == 5: # This follows the schema for tumors
        cancer, mycn_gene, amp_or_non_amp_v1, sample_type, patient_info = row["Patient_info_parsed"]
        patient_info_split = patient_info.split("_")
        patient_info_split_dict[len(patient_info_split)] += 1 # To count the distribution
        
        if mycn_gene == "Unknown":
            # ['NB', 'Unknown', 'Tumor', 'NCI0017', 'T3']
            cancer, mycn_gene, sample_type, patient_info, t_level = row["Patient_info_parsed"]
            print("T level", t_level)
            amp_or_non_amp_v1 = None

        
        # if "Tumor" in amp_or_non_amp_v1:
        #     print(row["Patient"])
        #     print(row["Patient_info_parsed"])
        #     print("Found Tumor in amp_or_non_amp_v1")

        # print(row["Patient"])
        # print(row["Patient_info_parsed"])        
        # print("patient_info_split", patient_info_split)
    
        # List of patients to skip
        if row["Patient"] == "NB.MYCN.A.Tumor.PASHFA_D_Dead_Amplified":
            print("Skiping this patient [NB.MYCN.A.Tumor.PASHFA_D_Dead_Amplified] for further discussion") ## TODO: Discuss with the team on this patient
            continue
        if row["Patient"] == "NB.MYCN.A.Tumor.PASJZC_Alive_Amplified":
            print("Skiping this patient [NB.MYCN.A.Tumor.PASJZC_Alive_Amplified] for further discussion. This has patient_info length of 3. Missing Risk level") ## TODO: Discuss with the team on this patient
            continue
        
        # Patient Information may be of length 4 or 3 or 1
        if len(patient_info_split) == 4:
            print("Patient identification length is 4")
            patient_identification, status, risk_level, amp_or_non_amp = patient_info.split("_")
            if status in ["D", "R"]:
                print("Found D or R in risk_level")
                patient_identification, d_or_r, status, amp_or_non_amp = patient_info.split("_")
                risk_level = None
        elif len(patient_info_split) == 3:
            # print("Patient identification length is 3")
            patient_identification, status, amp_or_non_amp = patient_info.split("_") # Since missing rish level: For this patient specifically: NB.MYCN.A.Tumor.PASJZC_Alive_Amplified
            risk_level = None
        elif len(patient_info_split) == 1:
            # print("Patient identification length is 1")
            patient_identification = patient_info.split("_")[0]
            status, risk_level, amp_or_non_amp = None, None, None
        
        item = {
            "Patient": row["Patient"],
            "Patient_parsed": row["Patient_info_parsed"],
            "Cancer": cancer,
            "Tissue Location": None,
            "gene": mycn_gene,
            "Amplified/Not-amplified": amp_or_non_amp_v1,
            "Sample Type": sample_type,
            "Patient ID": patient_identification,
            "Status": status,
            "d_or_r": d_or_r,
            "Risk Level": risk_level,
            "Nonamplified/Amplified": amp_or_non_amp,
            "T_level": t_level if t_level is not None else None
        }
        patient_info_list.append(item)
    
    if row["Patient_info_parsed_length"] == 6:
        cancer, mycn_gene, amp_or_non_amp_v1, sample_type, patient_identification, t_level = row["Patient_info_parsed"]
        print(row["Patient"])
        print(row["Patient_info_parsed"])
        print("T level", t_level)
        if "Tumor" in amp_or_non_amp_v1:
            print("Found Tumor in amp_or_non_amp_v1")
        item = {
            "Patient": row["Patient"],
            "Patient_parsed": row["Patient_info_parsed"],
            "Cancer": cancer,
            "Tissue Location": None,
            "gene": mycn_gene,
            "Amplified/Not-amplified": amp_or_non_amp_v1,
            "Sample Type": sample_type,
            "Patient ID": patient_identification,
            "Status": status,
            "d_or_r": d_or_r,
            "Risk Level": risk_level,
            "Nonamplified/Amplified": amp_or_non_amp,
            "T_level": t_level
        }
        patient_info_list.append(item)
        
    if row["Patient_info_parsed_length"] == 4:
        cancer, unknown, sample_type, patient_info = row["Patient_info_parsed"]
        patient_info_split = patient_info.split("_")
        patient_info_split_dict_unknown[len(patient_info_split)] += 1 # To count the distribution
        
        ## TODO: Discuss this patient len(patient_info_split) = 4  # NB.Unknown.Tumor.PAPTCR_Dead_High.Risk_Unknown
        if len(patient_info_split) == 4:
            # print("Patient identification length is 4")
            # Eg. ['NB', 'Unknown', 'Tumor', 'PAPTCR_Dead_HighRisk_Unknown']
            patient_identification, status, risk_level, amp_or_non_amp = patient_info.split("_")
            item = {
                "Patient": row["Patient"],
                "Patient_parsed": row["Patient_info_parsed"],
                "Cancer": cancer,
                "Tissue Location": None,
                "gene": unknown,
                "Amplified/Not-amplified": None,
                "Sample Type": sample_type,
                "Patient ID": patient_identification,
                "Status": status,
                "d_or_r": d_or_r,
                "Risk Level": risk_level,
                "Nonamplified/Amplified": amp_or_non_amp,
                "T_level": None
            }
            patient_info_list.append(item)
        
        ## TODO: Discuss why some patients don't have MYCN as the gene # Eg. NB.Unknown.Tumor.NCI0017
        # print("Patient", row["Patient"])
        # print("patient_info_split", patient_info_split)
        if len(patient_info_split) == 1:
            # print("Patient identification length is 1")
            patient_identification = patient_info_split[0]
            item = {
                "Patient": row["Patient"],
                "Patient_parsed": row["Patient_info_parsed"],
                "Cancer": cancer,
                "Tissue Location": None,
                "gene": unknown,
                "Amplified/Not-amplified": None,
                "Sample Type": sample_type,
                "Patient ID": patient_identification,
                "Status": None,
                "d_or_r": d_or_r,
                "Risk Level": None,
                "Nonamplified/Amplified": None,
                "T_level": None
            }
            patient_info_list.append(item)
# Out:
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Skiping this patient [NB.MYCN.A.Tumor.PASJZC_Alive_Amplified] for further discussion. This has patient_info length of 3. Missing Risk level
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Skiping this patient [NB.MYCN.A.Tumor.PASHFA_D_Dead_Amplified] for further discussion
# NB.MYCN.A.Tumor.NCI0102.T2
# ['NB', 'MYCN', 'A', 'Tumor', 'NCI0102', 'T2']
# T level T2
# NB.MYCN.A.Tumor.NCI0136.T2
# ['NB', 'MYCN', 'A', 'Tumor', 'NCI0136', 'T2']
# T level T2
# NB.MYCN.A.Tumor.NCI0138.T1
# ['NB', 'MYCN', 'A', 'Tumor', 'NCI0138', 'T1']
# T level T1
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# Patient identification length is 4
# Found D or R in risk_level
# T level T3
# T level T4

# %%
print("Distrituion of Patient_info_parsed_length for length = 6", patient_info_split_dict)
print("Distribution of Patient_info_parsed_length for length = 4", patient_info_split_dict_unknown)
# Out:
# Distrituion of Patient_info_parsed_length for length = 6 defaultdict(<class 'int'>, {4: 143, 3: 17, 1: 33})
# Distribution of Patient_info_parsed_length for length = 4 defaultdict(<class 'int'>, {4: 1, 1: 9})

# %%
tumor_patient_info_list_df = pd.DataFrame(patient_info_list)
tumor_patient_info_list_df
# Out:
#                                               Patient  \
# 0    NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1    NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 2    NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 3    NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 4    NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# ..                                                ...
# 199                       NB.Unknown.Tumor.NCI0017.T3
# 200                       NB.Unknown.Tumor.NCI0017.T4
# 201                          NB.Unknown.Tumor.NCI0108
# 202                          NB.Unknown.Tumor.NCI0117
# 203                          NB.Unknown.Tumor.NCI0231
#
#                                         Patient_parsed Cancer Tissue Location  \
# 0    [NB, MYCN, A, Tumor, PALEVG_Alive_HighRisk_Amp...     NB            None
# 1    [NB, MYCN, A, Tumor, PALKUC_Alive_HighRisk_Amp...     NB            None
# 2    [NB, MYCN, A, Tumor, PALZZV_Alive_HighRisk_Amp...     NB            None
# 3    [NB, MYCN, A, Tumor, PAMZGT_Alive_HighRisk_Amp...     NB            None
# 4    [NB, MYCN, A, Tumor, PAPBJE_Alive_HighRisk_Amp...     NB            None
# ..                                                 ...    ...             ...
# 199                  [NB, Unknown, Tumor, NCI0017, T3]     NB            None
# 200                  [NB, Unknown, Tumor, NCI0017, T4]     NB            None
# 201                      [NB, Unknown, Tumor, NCI0108]     NB            None
# 202                      [NB, Unknown, Tumor, NCI0117]     NB            None
# 203                      [NB, Unknown, Tumor, NCI0231]     NB            None
#
#         gene Amplified/Not-amplified Sample Type Patient ID Status d_or_r  \
# 0       MYCN                       A       Tumor     PALEVG  Alive   None
# 1       MYCN                       A       Tumor     PALKUC  Alive   None
# 2       MYCN                       A       Tumor     PALZZV  Alive   None
# 3       MYCN                       A       Tumor     PAMZGT  Alive   None
# 4       MYCN                       A       Tumor     PAPBJE  Alive   None
# ..       ...                     ...         ...        ...    ...    ...
# 199  Unknown                    None       Tumor    NCI0017   None   None
# 200  Unknown                    None       Tumor    NCI0017   None   None
# 201  Unknown                    None       Tumor    NCI0108   None   None
# 202  Unknown                    None       Tumor    NCI0117   None   None
# 203  Unknown                    None       Tumor    NCI0231   None   None
#
#     Risk Level Nonamplified/Amplified T_level
# 0     HighRisk              Amplified    None
# 1     HighRisk              Amplified    None
# 2     HighRisk              Amplified    None
# 3     HighRisk              Amplified    None
# 4     HighRisk              Amplified    None
# ..         ...                    ...     ...
# 199       None                   None      T3
# 200       None                   None      T4
# 201       None                   None    None
# 202       None                   None    None
# 203       None                   None    None
#
# [204 rows x 13 columns]

# %%
# patient_info_list_df["Cancer"].value_counts()
# patient_info_list_df["gene"].value_counts()
# patient_info_list_df["Amplified/Not-amplified"].value_counts()
# patient_info_list_df["Sample Type"].value_counts()
# patient_info_list_df["Patient ID"].value_counts()
# patient_info_list_df["Status"].value_counts()
# patient_info_list_df["d_or_r"].value_counts()
# patient_info_list_df["Risk Level"].value_counts()
# patient_info_list_df["Nonamplified/Amplified"].value_counts()
# patient_info_list_df["T_level"].value_counts()
## TODO: Identified some patients duplicates. Eg. PASNPG, PAUDDK etc. 198 unique patients with turmor found
## TODO: Discuss some patients with Status value as Alive, Dead, R, D etc.

# %%
# Schema
## Tumor
# Cancer.MYCN gene.Not amplified/Amplified.Sample Type.Patient ID.Status.Risk Level.Nonamplified/Amplified

## CellLine
# Cancer. MYCN gene. Amplified/Not-amplified.Sample Type.Patient ID)

## NS
# Normal sample. Location of tissue. Identification

# "Patient": row["Patient"],
# "Patient_parsed": row["Patient_info_parsed"],
# "Cancer": cancer,
# "gene": unknown,
# "Amplified/Not-amplified": None,
# "Sample Type": sample_type,
# "Patient ID": patient_identification,
# "Status": None,
# "d_or_r": d_or_r,
# "Risk Level": None,
# "Nonamplified/Amplified": None,
# "T_level": None

# %%
cellline_patients_df = temp_df[temp_df["Sample Type"] == "CellLine"]
cellline_patients_df

cellline_patient_info_list_df = None
cellline_patient_info_list = []

for id, row in cellline_patients_df.iterrows():
    cancer, mycn_gene, amp_or_non_amp_v1, sample_type, patient_identification = row["Patient_info_parsed"]
    item = {
        "Patient": row["Patient"],
        "Patient_parsed": row["Patient_info_parsed"],
        "Cancer": cancer,
        "Tissue Location": None,
        "gene": mycn_gene,
        "Amplified/Not-amplified": amp_or_non_amp_v1,
        "Sample Type": sample_type,
        "Patient ID": patient_identification,
        "Status": None,
        "d_or_r": None,
        "Risk Level": None,
        "Nonamplified/Amplified": None,
        "T_level": None
    }
    cellline_patient_info_list.append(item)

cellline_patient_info_list_df = pd.DataFrame(cellline_patient_info_list)

# %%
cellline_patient_info_list_df
# Out:
#                         Patient                     Patient_parsed Cancer  \
# 0     NB.MYCN.A.CellLine.CHP134    [NB, MYCN, A, CellLine, CHP134]     NB
# 1    NB.MYCN.A.CellLine.CHP-212   [NB, MYCN, A, CellLine, CHP-212]     NB
# 2    NB.MYCN.A.CellLine.COGN415   [NB, MYCN, A, CellLine, COGN415]     NB
# 3    NB.MYCN.A.CellLine.COGN440   [NB, MYCN, A, CellLine, COGN440]     NB
# 4    NB.MYCN.A.CellLine.COGN453   [NB, MYCN, A, CellLine, COGN453]     NB
# 5    NB.MYCN.A.CellLine.COGN471   [NB, MYCN, A, CellLine, COGN471]     NB
# 6    NB.MYCN.A.CellLine.COGN496   [NB, MYCN, A, CellLine, COGN496]     NB
# 7    NB.MYCN.A.CellLine.COGN519   [NB, MYCN, A, CellLine, COGN519]     NB
# 8    NB.MYCN.A.CellLine.COGN561   [NB, MYCN, A, CellLine, COGN561]     NB
# 9    NB.MYCN.A.CellLine.COGN573   [NB, MYCN, A, CellLine, COGN573]     NB
# 10     NB.MYCN.A.CellLine.GILIN     [NB, MYCN, A, CellLine, GILIN]     NB
# 11     NB.MYCN.A.CellLine.IMR32     [NB, MYCN, A, CellLine, IMR32]     NB
# 12      NB.MYCN.A.CellLine.IMR5      [NB, MYCN, A, CellLine, IMR5]     NB
# 13      NB.MYCN.A.CellLine.KCNR      [NB, MYCN, A, CellLine, KCNR]     NB
# 14     NB.MYCN.A.CellLine.KELLY     [NB, MYCN, A, CellLine, KELLY]     NB
# 15      NB.MYCN.A.CellLine.LAN1      [NB, MYCN, A, CellLine, LAN1]     NB
# 16      NB.MYCN.A.CellLine.LAN5      [NB, MYCN, A, CellLine, LAN5]     NB
# 17       NB.MYCN.A.CellLine.NB1       [NB, MYCN, A, CellLine, NB1]     NB
# 18    NB.MYCN.A.CellLine.NB1643    [NB, MYCN, A, CellLine, NB1643]     NB
# 19    NB.MYCN.A.CellLine.NB1691    [NB, MYCN, A, CellLine, NB1691]     NB
# 20      NB.MYCN.A.CellLine.NBSD      [NB, MYCN, A, CellLine, NBSD]     NB
# 21       NB.MYCN.A.CellLine.NGP       [NB, MYCN, A, CellLine, NGP]     NB
# 22       NB.MYCN.A.CellLine.NLF       [NB, MYCN, A, CellLine, NLF]     NB
# 23       NB.MYCN.A.CellLine.NMB       [NB, MYCN, A, CellLine, NMB]     NB
# 24    NB.MYCN.A.CellLine.SKNBE2    [NB, MYCN, A, CellLine, SKNBE2]     NB
# 25     NB.MYCN.A.CellLine.SKNDZ     [NB, MYCN, A, CellLine, SKNDZ]     NB
# 26    NB.MYCN.A.CellLine.SMSKAN    [NB, MYCN, A, CellLine, SMSKAN]     NB
# 27    NB.MYCN.A.CellLine.SMSSAN    [NB, MYCN, A, CellLine, SMSSAN]     NB
# 28  NB.MYCN.NA.CellLine.COGN534  [NB, MYCN, NA, CellLine, COGN534]     NB
# 29  NB.MYCN.NA.CellLine.COGN549  [NB, MYCN, NA, CellLine, COGN549]     NB
# 30    NB.MYCN.NA.CellLine.FELIX    [NB, MYCN, NA, CellLine, FELIX]     NB
# 31     NB.MYCN.NA.CellLine.LAN6     [NB, MYCN, NA, CellLine, LAN6]     NB
# 32     NB.MYCN.NA.CellLine.NB16     [NB, MYCN, NA, CellLine, NB16]     NB
# 33     NB.MYCN.NA.CellLine.NB69     [NB, MYCN, NA, CellLine, NB69]     NB
# 34     NB.MYCN.NA.CellLine.NBEB     [NB, MYCN, NA, CellLine, NBEB]     NB
# 35     NB.MYCN.NA.CellLine.NBLS     [NB, MYCN, NA, CellLine, NBLS]     NB
# 36   NB.MYCN.NA.CellLine.SHSY5Y   [NB, MYCN, NA, CellLine, SHSY5Y]     NB
# 37    NB.MYCN.NA.CellLine.SKNAS    [NB, MYCN, NA, CellLine, SKNAS]     NB
# 38    NB.MYCN.NA.CellLine.SKNFI    [NB, MYCN, NA, CellLine, SKNFI]     NB
# 39    NB.MYCN.NA.CellLine.SKNSH    [NB, MYCN, NA, CellLine, SKNSH]     NB
#
#    Tissue Location  gene Amplified/Not-amplified Sample Type Patient ID  \
# 0             None  MYCN                       A    CellLine     CHP134
# 1             None  MYCN                       A    CellLine    CHP-212
# 2             None  MYCN                       A    CellLine    COGN415
# 3             None  MYCN                       A    CellLine    COGN440
# 4             None  MYCN                       A    CellLine    COGN453
# 5             None  MYCN                       A    CellLine    COGN471
# 6             None  MYCN                       A    CellLine    COGN496
# 7             None  MYCN                       A    CellLine    COGN519
# 8             None  MYCN                       A    CellLine    COGN561
# 9             None  MYCN                       A    CellLine    COGN573
# 10            None  MYCN                       A    CellLine      GILIN
# 11            None  MYCN                       A    CellLine      IMR32
# 12            None  MYCN                       A    CellLine       IMR5
# 13            None  MYCN                       A    CellLine       KCNR
# 14            None  MYCN                       A    CellLine      KELLY
# 15            None  MYCN                       A    CellLine       LAN1
# 16            None  MYCN                       A    CellLine       LAN5
# 17            None  MYCN                       A    CellLine        NB1
# 18            None  MYCN                       A    CellLine     NB1643
# 19            None  MYCN                       A    CellLine     NB1691
# 20            None  MYCN                       A    CellLine       NBSD
# 21            None  MYCN                       A    CellLine        NGP
# 22            None  MYCN                       A    CellLine        NLF
# 23            None  MYCN                       A    CellLine        NMB
# 24            None  MYCN                       A    CellLine     SKNBE2
# 25            None  MYCN                       A    CellLine      SKNDZ
# 26            None  MYCN                       A    CellLine     SMSKAN
# 27            None  MYCN                       A    CellLine     SMSSAN
# 28            None  MYCN                      NA    CellLine    COGN534
# 29            None  MYCN                      NA    CellLine    COGN549
# 30            None  MYCN                      NA    CellLine      FELIX
# 31            None  MYCN                      NA    CellLine       LAN6
# 32            None  MYCN                      NA    CellLine       NB16
# 33            None  MYCN                      NA    CellLine       NB69
# 34            None  MYCN                      NA    CellLine       NBEB
# 35            None  MYCN                      NA    CellLine       NBLS
# 36            None  MYCN                      NA    CellLine     SHSY5Y
# 37            None  MYCN                      NA    CellLine      SKNAS
# 38            None  MYCN                      NA    CellLine      SKNFI
# 39            None  MYCN                      NA    CellLine      SKNSH
#
#    Status d_or_r Risk Level Nonamplified/Amplified T_level
# 0    None   None       None                   None    None
# 1    None   None       None                   None    None
# 2    None   None       None                   None    None
# 3    None   None       None                   None    None
# 4    None   None       None                   None    None
# 5    None   None       None                   None    None
# 6    None   None       None                   None    None
# 7    None   None       None                   None    None
# 8    None   None       None                   None    None
# 9    None   None       None                   None    None
# 10   None   None       None                   None    None
# 11   None   None       None                   None    None
# 12   None   None       None                   None    None
# 13   None   None       None                   None    None
# 14   None   None       None                   None    None
# 15   None   None       None                   None    None
# 16   None   None       None                   None    None
# 17   None   None       None                   None    None
# 18   None   None       None                   None    None
# 19   None   None       None                   None    None
# 20   None   None       None                   None    None
# 21   None   None       None                   None    None
# 22   None   None       None                   None    None
# 23   None   None       None                   None    None
# 24   None   None       None                   None    None
# 25   None   None       None                   None    None
# 26   None   None       None                   None    None
# 27   None   None       None                   None    None
# 28   None   None       None                   None    None
# 29   None   None       None                   None    None
# 30   None   None       None                   None    None
# 31   None   None       None                   None    None
# 32   None   None       None                   None    None
# 33   None   None       None                   None    None
# 34   None   None       None                   None    None
# 35   None   None       None                   None    None
# 36   None   None       None                   None    None
# 37   None   None       None                   None    None
# 38   None   None       None                   None    None
# 39   None   None       None                   None    None

# %%
# Schema
## Tumor
# Cancer.MYCN gene.Not amplified/Amplified.Sample Type.Patient ID.Status.Risk Level.Nonamplified/Amplified

## CellLine
# Cancer. MYCN gene. Amplified/Not-amplified.Sample Type.Patient ID)

## NS
# Normal sample. Location of tissue. Identification

# %%
ns_patients_df = temp_df[temp_df["Sample Type"] == "NS"]
ns_patients_df
ns_patient_info_list_df = None
ns_patient_info_list = []

for id, row in ns_patients_df.iterrows():
    cancer, tissue_location, patient_identification = row["Patient_info_parsed"]
    item = {
        "Patient": row["Patient"],
        "Patient_parsed": row["Patient_info_parsed"],
        "Cancer": cancer,
        "Tissue Location": tissue_location,
        "gene": None,
        "Amplified/Not-amplified": None,
        "Sample Type": row["Sample Type"],
        "Patient ID": patient_identification,
        "Status": None,
        "d_or_r": None,
        "Risk Level": None,
        "Nonamplified/Amplified": None,
        "T_level": None
    }
    ns_patient_info_list.append(item)

ns_patient_info_list_df = pd.DataFrame(ns_patient_info_list)

# %%
print(ns_patient_info_list_df.columns)
print(cellline_patient_info_list_df.columns)
print(tumor_patient_info_list_df.columns)
# Out:
# Index(['Patient', 'Patient_parsed', 'Cancer', 'Tissue Location', 'gene',
#        'Amplified/Not-amplified', 'Sample Type', 'Patient ID', 'Status',
#        'd_or_r', 'Risk Level', 'Nonamplified/Amplified', 'T_level'],
#       dtype='object')
# Index(['Patient', 'Patient_parsed', 'Cancer', 'Tissue Location', 'gene',
#        'Amplified/Not-amplified', 'Sample Type', 'Patient ID', 'Status',
#        'd_or_r', 'Risk Level', 'Nonamplified/Amplified', 'T_level'],
#       dtype='object')
# Index(['Patient', 'Patient_parsed', 'Cancer', 'Tissue Location', 'gene',
#        'Amplified/Not-amplified', 'Sample Type', 'Patient ID', 'Status',
#        'd_or_r', 'Risk Level', 'Nonamplified/Amplified', 'T_level'],
#       dtype='object')

# %%
final_df = pd.concat([tumor_patient_info_list_df, cellline_patient_info_list_df, ns_patient_info_list_df])
final_df
# Out:
#                                               Patient  \
# 0    NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1    NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 2    NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 3    NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 4    NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# ..                                                ...
# 142                                   NS.uterus.NS178
# 143                                   NS.uterus.NS180
# 144                                   NS.uterus.NS186
# 145                                   NS.uterus.NS184
# 146                                   NS.uterus.NS181
#
#                                         Patient_parsed Cancer Tissue Location  \
# 0    [NB, MYCN, A, Tumor, PALEVG_Alive_HighRisk_Amp...     NB            None
# 1    [NB, MYCN, A, Tumor, PALKUC_Alive_HighRisk_Amp...     NB            None
# 2    [NB, MYCN, A, Tumor, PALZZV_Alive_HighRisk_Amp...     NB            None
# 3    [NB, MYCN, A, Tumor, PAMZGT_Alive_HighRisk_Amp...     NB            None
# 4    [NB, MYCN, A, Tumor, PAPBJE_Alive_HighRisk_Amp...     NB            None
# ..                                                 ...    ...             ...
# 142                                [NS, uterus, NS178]     NS          uterus
# 143                                [NS, uterus, NS180]     NS          uterus
# 144                                [NS, uterus, NS186]     NS          uterus
# 145                                [NS, uterus, NS184]     NS          uterus
# 146                                [NS, uterus, NS181]     NS          uterus
#
#      gene Amplified/Not-amplified Sample Type Patient ID Status d_or_r  \
# 0    MYCN                       A       Tumor     PALEVG  Alive   None
# 1    MYCN                       A       Tumor     PALKUC  Alive   None
# 2    MYCN                       A       Tumor     PALZZV  Alive   None
# 3    MYCN                       A       Tumor     PAMZGT  Alive   None
# 4    MYCN                       A       Tumor     PAPBJE  Alive   None
# ..    ...                     ...         ...        ...    ...    ...
# 142  None                    None          NS      NS178   None   None
# 143  None                    None          NS      NS180   None   None
# 144  None                    None          NS      NS186   None   None
# 145  None                    None          NS      NS184   None   None
# 146  None                    None          NS      NS181   None   None
#
#     Risk Level Nonamplified/Amplified T_level
# 0     HighRisk              Amplified    None
# 1     HighRisk              Amplified    None
# 2     HighRisk              Amplified    None
# 3     HighRisk              Amplified    None
# 4     HighRisk              Amplified    None
# ..         ...                    ...     ...
# 142       None                   None    None
# 143       None                   None    None
# 144       None                   None    None
# 145       None                   None    None
# 146       None                   None    None
#
# [391 rows x 13 columns]

# %%
# uncomment to save to data/preprocessed folder
# final_df.to_csv("../data/preprocessed/patient_info_metadata.csv", index=False)

# %%
gene_expression_df
# Out:
#            Unnamed: 0  Sample Type  \
# 0          Ensembl ID  Gene Symbol
# 1     ENSG00000121410         A1BG
# 2     ENSG00000175899          A2M
# 3     ENSG00000166535        A2ML1
# 4     ENSG00000128274       A4GALT
# ...               ...          ...
# 6127  ENSG00000204375       XAGE1E
# 6128  ENSG00000185751        XAGE2
# 6129  ENSG00000171402        XAGE3
# 6130  ENSG00000171405        XAGE5
# 6131  ENSG00000175809       ZNF645
#
#                                                  Tumor  \
# 0     NB.MYCN.A.Tumor.PALEVG_Alive_High.Risk_Amplified
# 1                                             0.987836
# 2                                             4.771729
# 3                                                    0
# 4                                             0.940922
# ...                                                ...
# 6127                                          0.015002
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.1  \
# 0     NB.MYCN.A.Tumor.PALKUC_Alive_High.Risk_Amplified
# 1                                             1.458878
# 2                                              6.10215
# 3                                                    0
# 4                                             2.478532
# ...                                                ...
# 6127                                                 0
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.2  \
# 0     NB.MYCN.A.Tumor.PALZZV_Alive_High.Risk_Amplified
# 1                                             0.879737
# 2                                             3.064619
# 3                                             0.006537
# 4                                             0.332491
# ...                                                ...
# 6127                                                 0
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.3  \
# 0     NB.MYCN.A.Tumor.PAMZGT_Alive_High.Risk_Amplified
# 1                                             1.759617
# 2                                             6.210056
# 3                                                    0
# 4                                             2.228315
# ...                                                ...
# 6127                                                 0
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                          0.031542
#
#                                                Tumor.4  \
# 0     NB.MYCN.A.Tumor.PAPBJE_Alive_High.Risk_Amplified
# 1                                             2.410172
# 2                                             6.710592
# 3                                             0.003568
# 4                                             2.819369
# ...                                                ...
# 6127                                          0.146121
# 6128                                                 0
# 6129                                                 0
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.5  \
# 0     NB.MYCN.A.Tumor.PAPUNH_Alive_High.Risk_Amplified
# 1                                             1.917251
# 2                                             2.215601
# 3                                              0.01766
# 4                                              0.35549
# ...                                                ...
# 6127                                          0.153385
# 6128                                                 0
# 6129                                          0.033376
# 6130                                          0.299215
# 6131                                                 0
#
#                                                Tumor.6  \
# 0     NB.MYCN.A.Tumor.PAPZYP_Alive_High.Risk_Amplified
# 1                                             1.440319
# 2                                             6.152289
# 3                                                    0
# 4                                             2.173267
# ...                                                ...
# 6127                                          0.080812
# 6128                                                 0
# 6129                                           0.03838
# 6130                                                 0
# 6131                                                 0
#
#                                                Tumor.7  ...           NS.137  \
# 0     NB.MYCN.A.Tumor.PAPZYZ_Alive_High.Risk_Amplified  ...  NS.ureter.NS171
# 1                                             1.785339  ...         0.665534
# 2                                               7.6245  ...         6.363013
# 3                                                    0  ...         0.091691
# 4                                             3.358186  ...         2.850943
# ...                                                ...  ...              ...
# 6127                                          0.139717  ...                0
# 6128                                                 0  ...                0
# 6129                                                 0  ...                0
# 6130                                          0.045085  ...                0
# 6131                                                 0  ...                0
#
#                NS.138           NS.139           NS.140           NS.141  \
# 0     NS.ureter.NS172  NS.ureter.NS173  NS.uterus.NS185  NS.uterus.NS177
# 1            0.879104         0.421156         0.660868         0.553003
# 2            6.806819         6.139101         7.107079          6.54423
# 3            0.131466         0.150304         0.007645         0.058151
# 4            4.178136         4.003085         3.406599         1.636608
# ...               ...              ...              ...              ...
# 6127                0                0                0                0
# 6128                0                0                0                0
# 6129                0                0                0                0
# 6130                0                0                0                0
# 6131         0.102763                0                0                0
#
#                NS.142           NS.143           NS.144           NS.145  \
# 0     NS.uterus.NS178  NS.uterus.NS180  NS.uterus.NS186  NS.uterus.NS184
# 1            0.490898         0.550141         0.569498         0.438346
# 2            7.305137         6.714097          6.78923         6.761142
# 3            0.091356         0.068717         0.356167         0.094883
# 4            2.337835          1.67405         4.443948         1.905303
# ...               ...              ...              ...              ...
# 6127                0                0                0                0
# 6128                0                0                0                0
# 6129                0                0                0                0
# 6130                0                0                0                0
# 6131         0.097959         0.160879                0         0.026113
#
#                NS.146
# 0     NS.uterus.NS181
# 1            0.407911
# 2            7.126564
# 3            0.042002
# 4            2.331096
# ...               ...
# 6127                0
# 6128                0
# 6129                0
# 6130                0
# 6131         0.050632
#
# [6132 rows x 395 columns]

# %%
ensembl_id_list = None
gene_list = None
patient_list = []
for id, row in gene_expression_df.T.reset_index().iterrows():
    if id == 0:
        ensembl_id_list = row[2:].tolist()
    if id == 1: 
        gene_list = row[2:].tolist()
    if id >= 2:
        patient_name = row[0]
        gene_expression = list(row[2:])        
        patient_list.append({patient_name: gene_expression})

# %%
patient_names = []
patient_gene_expression = []
for x in patient_list:
    for k, v in x.items():
        patient_names.append(k)
        patient_gene_expression.append(v)

# %%
gene_expression_df_per_patient =pd.DataFrame(patient_gene_expression)
gene_expression_df_per_patient.columns = gene_list
gene_expression_df_per_patient["Patient"] = patient_names
gene_expression_df_per_patient.columns
gene_expression_df_per_patient = gene_expression_df_per_patient[["Patient"] + [x for x in list(gene_expression_df_per_patient.columns) if x != "Patient"]]

# %%
# Uncomment to save the file
# gene_expression_df_per_patient.to_csv("../data/preprocessed/gene_expression_per_patient.csv", index=False)

# %%
output_df = pd.merge(final_df, gene_expression_df_per_patient, left_on="Patient", right_on="Patient", how="left")

# %%
# Uncomment to save the file
# output_df.to_csv("../data/preprocessed/patient_info_metadata_gene_expression.csv", index=False)
